# %%
import pandas as pd
from utils.config import load_config
from utils.shared import get_model_by_name, save_model
from utils.training import get_tuned_hyperparameters, train_model

# %%
config = load_config()

# %%
for model_name in config.models:
    for data_dim in config.sample_sizes:

        print(
            f"Start training {model_name} model for {data_dim}x{config.train_samples_num} data..."
        )

        hyperparams = get_tuned_hyperparameters(model_name, data_dim)
        estimator = get_model_by_name(model_name, config.random_seed, config.n_jobs)
        data = pd.read_csv(
            f"{config.data_dir}/{config.train_data_subdir}/fbm_{data_dim}x{config.train_samples_num}.csv"
        )

        model = train_model(
            experiment_name=config.training_experiment_name,
            run_name=f"{model_name}_{data_dim}",
            estimator=estimator,
            hyperparams=hyperparams,
            X_train=data.drop(columns=[config.target_column]),
            y_train=data[config.target_column],
        )

        save_model(
            model,
            f"models/{model_name}_{data_dim}.joblib"
        )
# Out:
# Start training MLP model for 50x100000 data...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 14
#       9 estimator = get_model_by_name(model_name, config.random_seed, config.n_jobs)
#      10 data = pd.read_csv(
#      11     f"{config.data_dir}/{config.train_data_subdir}/fbm_{data_dim}x{config.train_samples_num}.csv"
#      12 )
# ---> 14 model = train_model(
#      15     experiment_name=config.training_experiment_name,
#      16     run_name=f"{model_name}_{data_dim}",
#      17     estimator=estimator,
#      18     hyperparams=hyperparams,
#      19     X_train=data.drop(columns=[config.target_column]),
#      20     y_train=data[config.target_column],
#      21 )
#      23 save_model(
#      24     model,
#      25     f"models/{model_name}_{data_dim}.joblib"
#      26 )
#
# File c:\Users\Zhenia\Desktop\ml_fbm_2\utils\training.py:40, in train_model(experiment_name, run_name, estimator, hyperparams, X_train, y_train)
#      34 mlflow.set_experiment(experiment_id=experiment_id)
#      36 with mlflow.start_run(
#      37     experiment_id=experiment_id,
#      38     run_name=run_name + "_" + str(uuid.uuid4())[:5],
#      39 ):
# ---> 40     estimator.set_params(**hyperparams)
#      41     estimator.fit(X_train, y_train)
#      43     # Linear models
#
# File c:\Users\Zhenia\Desktop\ml_fbm_2\.venv\Lib\site-packages\sklearn\base.py:345, in BaseEstimator.set_params(self, **params)
#     343 if key not in valid_params:
#     344     local_valid_params = self._get_param_names()
# --> 345     raise ValueError(
#     346         f"Invalid parameter {key!r} for estimator {self}. "
#     347         f"Valid parameters are: {local_valid_params!r}."
#     348     )
#     350 if delim:
#     351     nested_params[key][sub_key] = value
#
# ValueError: Invalid parameter 'n_layers' for estimator MLPRegressor(random_state=42). Valid parameters are: ['activation', 'alpha', 'batch_size', 'beta_1', 'beta_2', 'early_stopping', 'epsilon', 'hidden_layer_sizes', 'learning_rate', 'learning_rate_init', 'loss', 'max_fun', 'max_iter', 'momentum', 'n_iter_no_change', 'nesterovs_momentum', 'power_t', 'random_state', 'shuffle', 'solver', 'tol', 'validation_fraction', 'verbose', 'warm_start'].
