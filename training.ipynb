# %%
import pandas as pd
from utils.config import load_config
from utils.shared import get_model_by_name, save_model
from utils.training import get_tuned_hyperparameters, train_model

# %%
config = load_config()

# %%
for model_name in config.models:
    for data_dim in config.sample_sizes:

        print(
            f"Start training {model_name} model for {data_dim}x{config.train_samples_num} data..."
        )

        hyperparams = get_tuned_hyperparameters(model_name, data_dim)
        estimator = get_model_by_name(model_name, config.random_seed, config.n_jobs)
        data = pd.read_csv(
            f"{config.data_dir}/{config.train_data_subdir}/fbm_{data_dim}x{config.train_samples_num}.csv"
        )

        model = train_model(
            experiment_name=config.training_experiment_name,
            run_name=f"{model_name}_{data_dim}",
            estimator=estimator,
            hyperparams=hyperparams,
            X_train=data.drop(columns=[config.target_column]),
            y_train=data[config.target_column],
        )

        save_model(
            model,
            f"models/{model_name}_{data_dim}.joblib"
        )
# Out:
# Start training Ridge model for 25x100000 data...
# 2025/10/19 17:03:30 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training Ridge model for 50x100000 data...
# 2025/10/19 17:03:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training Ridge model for 100x100000 data...
# 2025/10/19 17:03:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training Lasso model for 25x100000 data...
# 2025/10/19 17:03:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training Lasso model for 50x100000 data...
# 2025/10/19 17:03:59 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training Lasso model for 100x100000 data...
# 2025/10/19 17:04:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training DecisionTree model for 25x100000 data...
# 2025/10/19 17:04:17 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training DecisionTree model for 50x100000 data...
# 2025/10/19 17:04:33 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training DecisionTree model for 100x100000 data...
# 2025/10/19 17:04:58 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training RandomForest model for 25x100000 data...
# 2025/10/19 17:08:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training RandomForest model for 50x100000 data...
# 2025/10/19 17:12:57 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training RandomForest model for 100x100000 data...
# 2025/10/19 17:19:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training LightGBM model for 25x100000 data...
# [LightGBM] [Warning] lambda_l1 is set=5.684833149487733, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.684833149487733
# [LightGBM] [Warning] lambda_l2 is set=5.877502942329619, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.877502942329619
# [LightGBM] [Warning] lambda_l1 is set=5.684833149487733, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.684833149487733
# [LightGBM] [Warning] lambda_l2 is set=5.877502942329619, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.877502942329619
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008153 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6375
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 25
# [LightGBM] [Info] Start training from score 0.499876
# 2025/10/19 17:19:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training LightGBM model for 50x100000 data...
# [LightGBM] [Warning] lambda_l1 is set=1.028956687751779, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.028956687751779
# [LightGBM] [Warning] lambda_l2 is set=2.885097174920504, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.885097174920504
# [LightGBM] [Warning] lambda_l1 is set=1.028956687751779, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.028956687751779
# [LightGBM] [Warning] lambda_l2 is set=2.885097174920504, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.885097174920504
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012647 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12750
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 50
# [LightGBM] [Info] Start training from score 0.501539
# 2025/10/19 17:19:44 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training LightGBM model for 100x100000 data...
# [LightGBM] [Warning] lambda_l1 is set=1.3073921374446917, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3073921374446917
# [LightGBM] [Warning] lambda_l2 is set=1.2489947519779787, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.2489947519779787
# [LightGBM] [Warning] lambda_l1 is set=1.3073921374446917, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3073921374446917
# [LightGBM] [Warning] lambda_l2 is set=1.2489947519779787, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.2489947519779787
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024864 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 25500
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 100
# [LightGBM] [Info] Start training from score 0.500586
# 2025/10/19 17:20:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training XGBoost model for 25x100000 data...
# 2025/10/19 17:21:00 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training XGBoost model for 50x100000 data...
# 2025/10/19 17:21:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Start training XGBoost model for 100x100000 data...
# 2025/10/19 17:21:39 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
